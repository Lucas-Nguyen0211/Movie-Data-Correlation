# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv(r"C:\Users\Administrator\Downloads\Python\movies.csv")

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# Kiểm tra xem có dữ liệu missing hay không?

# %%
# Kiểm tra xem có dữ liệu missing hay không?
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}: {}%'.format(col, pct_missing))
# Out:
# name: 0.0%
# rating: 0.010041731872717789%
# genre: 0.0%
# year: 0.0%
# released: 0.0002608242044861763%
# score: 0.0003912363067292645%
# votes: 0.0003912363067292645%
# director: 0.0%
# writer: 0.0003912363067292645%
# star: 0.00013041210224308815%
# country: 0.0003912363067292645%
# budget: 0.2831246739697444%
# gross: 0.02464788732394366%
# company: 0.002217005738132499%
# runtime: 0.0005216484089723526%

# %%
# Xoá hàng có giá trị NA
df = df.dropna(axis = 0)

# %%
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{}: {}%'.format(col, pct_missing))
# Out:
# name: 0.0%
# rating: 0.0%
# genre: 0.0%
# year: 0.0%
# released: 0.0%
# score: 0.0%
# votes: 0.0%
# director: 0.0%
# writer: 0.0%
# star: 0.0%
# country: 0.0%
# budget: 0.0%
# gross: 0.0%
# company: 0.0%
# runtime: 0.0%

# %%
# Data type cột
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Chuyển gross và budget về kiểu số nguyên
df["budget"] = df["budget"].astype("int64")

df["gross"] = df["gross"].astype("int64")

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score      votes  \
# ...

# %%
#pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
#Xoá hàng lặp
df = df.drop_duplicates()

# %%
#Tìm mối quan hệ tương quan giữa các cột trong DataFrame với nhau

# %%
# Ngân sách sẽ có tương quan / ảnh hưởng lớn với Doanh thu. 
# Tên công ty sẽ có tương quan / ảnh hưởng lớn với doanh thu.

# %%
# Đồ thị phân tán giữa ngân sách và doanh thu. 

plt.scatter(x = df["budget"], y = df["gross"])
plt.title("Budget vs. Gross")
plt.xlabel("Budget")
plt.ylabel("Gross")
plt.show()

# %% [markdown]
# Khó để nhận biết là budget có thực sự ảnh hưởng đến gross hay không

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# Scatter plot dùng seaborn

sns.regplot(x = "budget", y = "gross", data = df, line_kws = {"color": "blue"}, scatter_kws = {"color": "red"})
plt.show()

# %% [markdown]
# Dự đoán: Budget có tác động đến doanh thu.

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df_corr =  df[["year", "score", "votes", "budget", "gross", "runtime"]].corr(method = "pearson")

# %%
df_corr
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %% [markdown]
# Corr giữa budget và doanh thu là 0.74 là tỷ lệ khá cao
# Kết luận Budget ảnh hưởng đến gross là chính xác

# %%
sns.heatmap(df_corr, annot = True)

plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %%
df_numberized = df

for col_name in df_numberized:
    if df_numberized[col_name].dtype == "object":
        df_numberized[col_name] = df_numberized[col_name].astype("category")
        df_numberized[col_name] = df_numberized[col_name].cat.codes

# %%
df_numberized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country    budget      gross  company  runtime
# 0   699       46  19000000   46998772     1426    146.0
# 1   214       47   4500000   58853106      452    104.0
# 2  1157       47  18000000  538375067      945    124.0
# 3  1474       47   3500000   83453539     1108     88.0
# 4   271       47   6000000   39846344     1083     98.0

# %%
df_numberized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
sns.heatmap(df_numberized.corr(), annot = True)

plt.title("Correlation Matrix")
plt.xlabel("Movie Features")
plt.ylabel("Movie Features")

plt.show()

# %%
df_numberized_corr = df_numberized.corr()

# %%
df_numberized_corr
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.029234  0.010996  0.025542 -0.006152  0.014450
# rating   -0.029234  1.000000  0.147796  0.019499  0.018083  0.065983
# genre     0.010996  0.147796  1.000000 -0.073167  0.022142  0.035106
# year      0.025542  0.019499 -0.073167  1.000000 -0.001740  0.056386
# released -0.006152  0.018083  0.022142 -0.001740  1.000000  0.045874
# score     0.014450  0.065983  0.035106  0.056386  0.045874  1.000000
# votes     0.012615  0.006031 -0.135990  0.206021  0.028833  0.474256
# director  0.015246  0.014656 -0.008553 -0.038354  0.002308  0.005413
# writer    0.012880 -0.003149  0.017578 -0.025908  0.008072  0.012843
# star     -0.006882  0.009196  0.003341 -0.032157  0.015706  0.007296
# country  -0.025490  0.008230 -0.009164 -0.066748 -0.017228 -0.043051
# budget    0.023392 -0.203946 -0.368523  0.327722  0.019952  0.072001
# gross     0.005639 -0.181906 -0.244101  0.274321  0.008501  0.222556
# ...

# %%
corr_pair =  df_numberized_corr.unstack()

# %%
corr_pair
# Out:
# name      name        1.000000
#           rating     -0.029234
#           genre       0.010996
#           year        0.025542
#           released   -0.006152
#           score       0.014450
#           votes       0.012615
#           director    0.015246
#           writer      0.012880
#           star       -0.006882
#           country    -0.025490
#           budget      0.023392
#           gross       0.005639
#           company     0.021697
#           runtime     0.010850
# rating    name       -0.029234
#           rating      1.000000
#           genre       0.147796
#           year        0.019499
#           released    0.018083
#           score       0.065983
#           votes       0.006031
#           director    0.014656
#           writer     -0.003149
#           star        0.009196
#           country     0.008230
#           budget     -0.203946
#           gross      -0.181906
#           company    -0.092357
#           runtime     0.140792
# ...

# %%
sort_pair = corr_pair.sort_values()
sort_pair
# Out:
# budget    genre      -0.368523
# genre     budget     -0.368523
#           gross      -0.244101
# gross     genre      -0.244101
# budget    rating     -0.203946
# rating    budget     -0.203946
#           gross      -0.181906
# gross     rating     -0.181906
# genre     votes      -0.135990
# votes     genre      -0.135990
# company   rating     -0.092357
# rating    company    -0.092357
# genre     year       -0.073167
# year      genre      -0.073167
# genre     company    -0.071334
# company   genre      -0.071334
# year      country    -0.066748
# country   year       -0.066748
# genre     runtime    -0.059237
# runtime   genre      -0.059237
# country   score      -0.043051
# score     country    -0.043051
# budget    writer     -0.039466
# writer    budget     -0.039466
# director  year       -0.038354
# year      director   -0.038354
# writer    gross      -0.035885
# gross     writer     -0.035885
# country   runtime    -0.034477
# runtime   country    -0.034477
# ...

# %%
high_corr = sort_pair[sort_pair  > 0.5]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %% [markdown]
# - Như vậy có thể thấy Votes và ngân sách có ảnh hưởng lớn nhất tới doanh thu công ty.
# - Tên công ty không ảnh hưởng nhiều đến doanh thu như tôi nghĩ.
